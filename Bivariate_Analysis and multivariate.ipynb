# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('spotify_churn_dataset.csv')

# %%
df.columns
# Out:
# Index(['user_id', 'gender', 'age', 'country', 'subscription_type',
#        'listening_time', 'songs_played_per_day', 'skip_rate', 'device_type',
#        'ads_listened_per_week', 'offline_listening', 'is_churned'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   user_id                8000 non-null   int64
#  1   gender                 8000 non-null   object
#  2   age                    8000 non-null   int64
#  3   country                8000 non-null   object
#  4   subscription_type      8000 non-null   object
#  5   listening_time         8000 non-null   int64
#  6   songs_played_per_day   8000 non-null   int64
#  7   skip_rate              8000 non-null   float64
#  8   device_type            8000 non-null   object
#  9   ads_listened_per_week  8000 non-null   int64
#  10  offline_listening      8000 non-null   int64
#  11  is_churned             8000 non-null   int64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 750.1+ KB

# %%
df.describe()
# Out:
#           user_id          age  listening_time  songs_played_per_day  \
# count  8000.00000  8000.000000     8000.000000           8000.000000
# mean   4000.50000    37.662125      154.068250             50.127250
# std    2309.54541    12.740359       84.015596             28.449762
# min       1.00000    16.000000       10.000000              1.000000
# 25%    2000.75000    26.000000       81.000000             25.000000
# 50%    4000.50000    38.000000      154.000000             50.000000
# 75%    6000.25000    49.000000      227.000000             75.000000
# max    8000.00000    59.000000      299.000000             99.000000
#
#          skip_rate  ads_listened_per_week  offline_listening   is_churned
# count  8000.000000            8000.000000        8000.000000  8000.000000
# mean      0.300127               6.943875           0.747750     0.258875
# std       0.173594              13.617953           0.434331     0.438044
# ...

# %%
df.isnull().sum()
# Out:
# user_id                  0
# gender                   0
# age                      0
# country                  0
# subscription_type        0
# listening_time           0
# songs_played_per_day     0
# skip_rate                0
# device_type              0
# ads_listened_per_week    0
# offline_listening        0
# is_churned               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    user_id  gender  age country subscription_type  listening_time  \
# 0        1  Female   54      CA              Free              26
# 1        2   Other   33      DE            Family             141
# 2        3    Male   38      AU           Premium             199
# 3        4  Female   22      CA           Student              36
# 4        5   Other   29      US            Family             250
#
#    songs_played_per_day  skip_rate device_type  ads_listened_per_week  \
# 0                    23       0.20     Desktop                     31
# 1                    62       0.34         Web                      0
# 2                    38       0.04      Mobile                      0
# 3                     2       0.31      Mobile                      0
# 4                    57       0.36      Mobile                      0
#
#    offline_listening  is_churned
# 0                  0           1
# 1                  1           0
# 2                  1           1
# ...

# %%
sns.countplot(x=df['country'],hue=df['gender'])
#plt.savefig('bmpic1.jpg')
# you can undo comment to save the pic
# Out:
# <Axes: xlabel='country', ylabel='count'>

# %%
sns.countplot(x=df['gender'],hue=df['subscription_type'])
#plt.savefig('bmpic2.jpg')
# you can undo comment to save the pic
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.barplot(data=df,x='gender',y='listening_time')
#plt.savefig('bmpic3.jpg')
# you can undo comment to save the pic
# Out:
# <Axes: xlabel='gender', ylabel='listening_time'>

# %%
sns.barplot(data=df,x='gender',y='songs_played_per_day')
#plt.savefig('bmpic4.jpg')
# you can undo comment to save the pic
# Out:
# <Axes: xlabel='gender', ylabel='songs_played_per_day'>

# %%
sns.barplot(data=df,x='country',y='skip_rate',hue='gender',color='r')
#plt.savefig('bmpic5.jpg')
# you can undo comment to save the pic
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_18260\3571875205.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:r'` for the same effect.
#
#   sns.barplot(data=df,x='country',y='skip_rate',hue='gender',color='r')
# <Axes: xlabel='country', ylabel='skip_rate'>

# %%
sns.barplot(data=df,x='country',y='songs_played_per_day',hue='gender',color='g')
#plt.savefig('bmpic6.jpg')
# you can undo comment to save the pic
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_18260\2877849977.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:g'` for the same effect.
#
#   sns.barplot(data=df,x='country',y='songs_played_per_day',hue='gender',color='g')
# <Axes: xlabel='country', ylabel='songs_played_per_day'>

# %%
sns.barplot(data=df,x='country',y='ads_listened_per_week',hue='gender',color='b')
#plt.savefig('bmpic7.jpg')
# you can undo comment to save the pic
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_18260\3069496458.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:b'` for the same effect.
#
#   sns.barplot(data=df,x='country',y='ads_listened_per_week',hue='gender',color='b')
# <Axes: xlabel='country', ylabel='ads_listened_per_week'>

# %%
sns.violinplot(data=df,x='country',y='age')
#plt.savefig('bmpic8.jpg')
# you can undo comment to save the pic
# Out:
# <Axes: xlabel='country', ylabel='age'>

# %%
sns.pairplot(df)
#plt.savefig('bmpic9.jpg')
# you can undo comment to save the pic
